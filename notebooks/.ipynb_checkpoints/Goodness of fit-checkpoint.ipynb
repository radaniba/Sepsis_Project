# %%
import scipy.stats
import pandas as pd

# %%
dists = ['uniform', 'norm', 'lognorm', 'expon', 'beta',
         'powerlaw', 'bradford', 'burr', 'fisk', 'cauchy', 'halfcauchy',
         'foldcauchy', 'gamma', 'gengamma', 'loggamma',
         'alpha', 'anglit', 'arcsine', 'betaprime', 'dgamma',
         'exponnorm', 'exponweib', 'exponpow', 'frechet_l', 'frechet_r',
         'gilbrat', 'f', 'ncf', 'chi2', 'chi', 'nakagami', 'genpareto',
         'genextreme', 'genhalflogistic', 'pareto', 'lomax', 'halfnorm',
         'halflogistic', 'fatiguelife', 'foldnorm', 'ncx2', 't', 'nct',
         'weibull_min', 'weibull_max', 'dweibull', 'maxwell', 'rayleigh',
         'genlogistic', 'logistic', 'gumbel_l', 'gumbel_r', 'gompertz',
         'hypsecant', 'laplace', 'reciprocal', 'trapz', 'triang', 'tukeylambda',
         'vonmises', 'vonmises_line', 'pearson3', 'gennorm', 'halfgennorm',
         'rice', 'kappa4', 'kappa3', 'truncnorm']

# %%
cytokines = pd.read_csv("../data/Nelly_cytokine_data_cast.csv", header=0, sep=",")

# %%
cytokines.drop(['Unnamed: 0','Site', 'Sample', 'Group', 'SEX', 'GEST_AGE', 'DELIVERY', 'MOM_AGE'], axis = 1, inplace = True, errors = 'ignore')

# %%
cytokines.head()
# Out:
#    LPS_IFNa2  LPS_IFNg  LPS_IL-10  LPS_IL-12p40  LPS_IL-12p70  LPS_IL-1b  \
# 0       0.00      0.00     407.55         34.01          0.00    1182.39
# 1       0.00    164.65     190.30        294.21          0.00    4854.15
# 2       4.36      9.95      25.01         25.50          0.00     918.03
# 3       0.00      0.00      48.22        243.46          0.69    1477.38
# 4       0.00    305.57     130.76        254.47          0.74    4194.74
#
#    LPS_IL-23  LPS_IL-6  LPS_IL-8  LPS_IP-10     ...       Unstim_IL-12p70  \
# 0         52  12854.94  25460.34     198.49     ...                  2.29
# 1        399  15484.07  10110.55    5332.88     ...                  2.29
# 2        158   4153.73   6037.95     602.40     ...                  2.29
# 3        124  19789.61  11631.42    5421.80     ...                  6.69
# 4        438  12298.07  11077.57    2834.02     ...                  8.80
#
#    Unstim_IL-1b  Unstim_IL-23  Unstim_IL-6  Unstim_IL-8  Unstim_IP-10  \
# 0         34.16             0        24.64        33.78         60.65
# 1         34.16             0        24.64        33.78         76.21
# 2         34.16             0        24.64        33.78         64.53
# 3         12.26             0        41.15        34.50        221.81
# 4         12.26             0        41.15        34.50        225.47
#
#    Unstim_MDC  Unstim_MIP-1a  Unstim_MIP-1b  Unstim_TNFa
# 0     4013.29          55.22          38.90        29.63
# 1     3984.62          94.92          38.90        29.63
# 2     4070.76           1.19          38.90        29.63
# 3     4433.17          38.40        3158.78        24.06
# 4     4463.60          38.40        3158.78        23.83
#
# [5 rows x 98 columns]

# %%
sample = cytokines['LPS_IL-12p40']
sample = scipy.stats.halflogistic(1,1).rvs(500)
results = pd.DataFrame(columns=('Sample', 'Distribution', 'Pvalue'))

# %%
max = 0
for dist in dists:
    #fit our data set against every probability distribution
    parameters = eval("scipy.stats."+dist+".fit(sample)");
    #Applying the Kolmogorov-Smirnof one sided test
    D, p = scipy.stats.kstest(sample, dist, args=parameters);
    #pretty-print the results
    print dist.ljust(16) + ("p: "+str(p)).ljust(25)+"D: "+str(D);
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-49-42ea8e085e6d> in <module>()
#       4     parameters = eval("scipy.stats."+dist+".fit(sample)");
#       5     #Applying the Kolmogorov-Smirnof one sided test
# ----> 6     D, p = scipy.stats.ks_2samp(sample, dist);
#       7     #pretty-print the results
#       8     print dist.ljust(16) + ("p: "+str(p)).ljust(25)+"D: "+str(D);
#
# /Users/raniba/anaconda/lib/python2.7/site-packages/scipy/stats/stats.pyc in ks_2samp(data1, data2)
#    4551     """
#    4552     data1 = np.sort(data1)
# -> 4553     data2 = np.sort(data2)
#    4554     n1 = data1.shape[0]
#    4555     n2 = data2.shape[0]
#
# /Users/raniba/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in sort(a, axis, kind, order)
#     823     else:
#     824         a = asanyarray(a).copy(order="K")
# --> 825     a.sort(axis, kind, order)
#     826     return a
#     827
#
# ValueError: axis(=-1) out of bounds

# %%
# Out:
# array([ 3.4539045 ,  2.45415362,  2.00595553,  2.18282534,  1.4428816 ,
#         2.67367622,  2.36978023,  2.86837969,  1.92565473,  1.11932972,
#         2.39500778,  1.05792012,  1.91784248,  2.81375593,  1.32414688,
#         1.07337738,  2.11028251,  8.35193232,  1.03851026,  1.8585513 ,
#         1.32941635,  2.0924999 ,  1.59291826,  2.72193174,  1.64651076,
#         1.30458409,  4.29560399,  1.68511218,  1.43669272,  3.41875949,
#         2.82457733,  2.30743228,  4.10130037,  1.94917049,  2.90374464,
#         2.26700448,  1.94513664,  2.42129838,  2.81083421,  2.33569624,
#         1.68993465,  3.62037179,  1.37789481,  2.31668587,  1.50675783,
#         3.2443884 ,  1.63621991,  1.26723518,  1.67599828,  1.47620228,
#         1.22207889,  1.98591449,  2.19559925,  2.42832147,  1.72317384,
#         4.83077909,  2.87244972,  2.9418805 ,  2.23031321,  1.03559334,
#         1.42004167,  2.37569818,  2.68041859,  1.55221559,  1.62277169,
#         1.9809553 ,  2.352654  ,  2.59485774,  3.81232722,  2.64577513,
#         2.01574444,  3.82696316,  1.76918982,  1.9015748 ,  2.44006565,
#         3.57207474,  1.34284727,  3.71140776,  1.3725978 ,  2.2177923 ,
#         1.70387612,  2.80638506,  2.23330869,  1.4992465 ,  3.21166646,
#         1.36567525,  1.19416699,  3.14760363,  1.25044219,  1.31327909,
#         2.63124882,  2.52363331,  1.95592292,  1.88043623,  2.03862433,
#         1.21307244,  3.75599266,  2.41996257,  1.76570205,  3.02210844,
#         2.60818655,  2.17965665,  1.6441736 ,  1.42112831,  1.19637046,
#         2.41830771,  2.4449925 ,  1.16794983,  5.28121074,  1.32813433,
